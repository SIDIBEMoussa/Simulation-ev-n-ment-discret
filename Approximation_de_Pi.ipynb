# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDIBEMoussa/Simulation-ev-n-ment-discret/blob/main/Approximation_de_Pi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pl
import math

# %%
def approxim_pi(N):
  M=np.random.rand(2,N)
  x,y=M[0][:],M[1][:]
  disque=x**2+y**2
  I=np.count_nonzero(disque<1)
  f=I/N
  pi=4*f
  return pi

# %%
#N=np.array([10,100,1000,10000,100000,1000000])
N=np.array(range(100,10000000,100000))
pi_array=[]
for n in N:
  pi_array.append(approxim_pi(n))
pi_array=np.array(pi_array)

# %%
pl.style.use("ggplot")
pl.rcParams.update({"font.size":13})
pl.figure(figsize=(12,6))
pl.title('Simulation de la valeur de $\pi$')
fig=pl.plot(N,pi_array)
pl.plot(N,math.pi*np.ones(len(N)),"r--")
pl.axis(ymin=3.13,ymax=3.15)
pl.xlabel("Nombre de points")
pl.ylabel("Valeur de $\pi$")
# Out:
# Text(0, 0.5, 'Valeur de $\\pi$')

# %% [markdown]
# En conclusion nous observons plus nous l'aire du disque est pleinement remplie plus on se rapproche de la valeur exacte de $\pi$

# %%
pi_array
# Out:
# array([3.04      , 3.15320679, 3.13865067, 3.13972676, 3.13696576,
#        3.14255549, 3.142003  , 3.14142551, 3.14515186, 3.14369514,
#        3.14314169, 3.14162349, 3.14038163, 3.14222291, 3.14309264,
#        3.14379041, 3.14324105, 3.13841539, 3.1405633 , 3.14354613,
#        3.14285286, 3.14312842, 3.14160629, 3.14299378, 3.14235074,
#        3.14162314, 3.14120072, 3.14075331, 3.14201921, 3.14247095,
#        3.14076197, 3.14081094, 3.14176682, 3.14102239, 3.14172524,
#        3.14219594, 3.14119941, 3.14234859, 3.14204468, 3.1433512 ,
#        3.14166846, 3.14170679, 3.14302802, 3.14190833, 3.14195496,
#        3.14185551, 3.14223256, 3.1420123 , 3.14166038, 3.14116691,
#        3.14278994, 3.13981294, 3.14219803, 3.14126903, 3.14294402,
#        3.14095671, 3.14149747, 3.14221224, 3.14031275, 3.14234877,
#        3.14170564, 3.14195636, 3.14138353, 3.14238568, 3.14239403,
#        3.14147044, 3.1422536 , 3.14207728, 3.14252261, 3.1428246 ,
# ...
